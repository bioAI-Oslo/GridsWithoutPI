# %%
import scipy
import torch
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("../")
from tqdm import tqdm
from models import RNNGC, FFGC
from dataset import DatasetMaker

# %%
## Training parameters
train_steps = 50000
timesteps = 10
bs = 64 # batch size

# Model parameters
ng = 256 # no. of recurrent units

# %%
# instantiate RNN model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

alpha = 0
# model = FFGC(alpha = alpha, norm = "l2")
model = RNNGC(alpha = alpha, norm = "l2")

# model = model.load("./saved-models/RNNGC.pkl")

model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)

# %%
dataset = DatasetMaker()

# %%
rt, vt = dataset.generate_data(10, timesteps, "cpu")

for i in range(10):
  plt.plot(rt[i,...,0], rt[i,...,1])
plt.axis(2*np.pi*np.array([-1, 1, -1, 1]))
# Out:
# (-6.283185307179586, 6.283185307179586, -6.283185307179586, 6.283185307179586)

# %%
loss_history = []
for i in tqdm(range(train_steps-len(model.total_loss_history))):
    r, v = dataset.generate_data(bs, timesteps, device)

    # loss = model.train_step(inputs = (r), labels = r, optimizer = optimizer)
    loss = model.train_step(inputs = (r[:,0], v), labels = r, optimizer = optimizer)

    loss_history.append(loss.item())
model.save(f"../saved-models/RNNGC_{i}_with_L2_alpha_{alpha}.pkl")
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# 100%|██████████| 50000/50000 [09:52<00:00, 84.42it/s]

# %%
fig,axs = plt.subplots(1,3,figsize=(9,3))
axs[0].semilogy(np.array(model.total_loss_history)-model.loss_minima())
axs[1].semilogy(np.array(model.capacity_loss_history)-model.loss_minima())
axs[2].semilogy(model.distance_loss_history)
fig.tight_layout()
# Out:
# /var/folders/rv/mky69fln76nbwl7qkb06318h0000gn/T/ipykernel_36162/3649732447.py:5: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   fig.tight_layout()

# %%
r, v = dataset.generate_data(10000, timesteps, device)
# g = model(r)
g = model((r[:,0], v))
r = r.detach().cpu().numpy()
g = g.detach().cpu().numpy()

# %%
ratemaps = scipy.stats.binned_statistic_2d(r[...,0].ravel(), r[...,1].ravel(), g.reshape(-1, g.shape[-1]).T, bins = 64)[0]

# %%
ns = 5 # ns x ns grid of unit ratemaps
count = 0
fig, ax = plt.subplots(ns,ns, figsize = (2,2))
for i in range(ns):
    for j in range(ns):
        im = ax[i,j].imshow(ratemaps[count])
        ax[i,j].axis("off")
        count += 1

# %%
sim = np.exp(np.sum(-(ratemaps - ratemaps[:,32,32][:,None,None])**2, axis = 0))
plt.imshow(sim) # spatial similarity with origin
plt.colorbar()
